# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('//content/nonlinear_temp_dataset.csv')
df
# Out:
#            date  meantemp
# 0    2017-01-01   20.7451
# 1    2017-01-02   21.4476
# 2    2017-01-03   24.1637
# 3    2017-01-04   26.7903
# 4    2017-01-05   25.1617
# ..          ...       ...
# 115  2017-04-26   32.8392
# 116  2017-04-27   32.8929
# 117  2017-04-28   31.4051
# 118  2017-04-29   34.6983
# 119  2017-04-30   33.5445
#
# [120 rows x 2 columns]

# %%
plt.scatter(df['date'], df['meantemp'], color='red')

# %%
x1=df['meantemp'].ewm(alpha=0.5).mean()

# %%
x1
# Out:
# 0      20.745100
# 1      21.213433
# 2      22.899300
# 3      24.974500
# 4      25.071119
#          ...
# 115    32.059664
# 116    32.476282
# 117    31.940691
# 118    33.319495
# 119    33.431998
# Name: meantemp, Length: 120, dtype: float64

# %%
df['ewm']=x1
df
# Out:
#            date  meantemp        ewm
# 0    2017-01-01   20.7451  20.745100
# 1    2017-01-02   21.4476  21.213433
# 2    2017-01-03   24.1637  22.899300
# 3    2017-01-04   26.7903  24.974500
# 4    2017-01-05   25.1617  25.071119
# ..          ...       ...        ...
# 115  2017-04-26   32.8392  32.059664
# 116  2017-04-27   32.8929  32.476282
# 117  2017-04-28   31.4051  31.940691
# 118  2017-04-29   34.6983  33.319495
# 119  2017-04-30   33.5445  33.431998
#
# [120 rows x 3 columns]

# %%
plt.scatter(df['date'], df['meantemp'], color='red')
plt.plot(df['ewm'], color='black')
