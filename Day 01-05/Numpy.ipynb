# %%
import numpy as np

# %%
a1= np.array([1,2,3,4])
a1

# %%
type(a1)

# %%
a2=np.array([[1,2,3,4],[5,8,2,9]])
a2
a2.shape

# %%
a3=np.array([[1.0,3.0,5.8],[6.0,7.2,4.3],[9.0,8.1,3.5]])
a3
a3.shape

# %%
a1.ndim, a2.ndim, a3.ndim

# %%
a1.dtype

# %%
a1.size, a2.size, a3.size
a3

# %%
import pandas as pd
df=pd.DataFrame(a3)
df

# %%
a4=np.ones((3,3))
a4

# %%
a4.dtype

# %%
zeros=np.zeros((2,4))
zeros

# %%
a5=np.arange(0,10,2)
a5

# %%
random=np.random.randint(0,10, size=(3,6,4))
random

# %%
r2=np.random.random((5,3))
r2

# %%
r3=np.random.rand(3,5,4)
r3

# %%
random

# %%
random[0]

# %%
random[:1 :2 ]

# %%
random2=np.random.randint(0,10, size=(2,3,3))
random2

# %%
random2[0]

# %%
random2[:, :1, :]

# %%
a1

# %%
a2

# %%
a1 + a2

# %%
a2-a1

# %%
b = a1*a2
b

# %%
b / a1

# %%
b // a1

# %%
b ** 2

# %%
np.add(a1,a2)

# %%
np.square(a2)

# %%
np.log(b)

# %%
np.sum(a1)

# %%
np.max(b)

# %%
np.mean(b)

# %%
np.std(b)

# %%
np.var(b)

# %%
np.sqrt(b)

# %%
np.sum(b)

# %%
#Variance will be large for wide range of numbers and low with low range of numbers
l1=np.array([100,200,300,400,500,600])
l2=np.array([2,4,6,8,10])

# %%
np.var(l1), np.var(l2)

# %%
np.std(l1), np.std(l2)

# %%
np.mean(l1), np.mean(l2)

# %%
#Reshaping and Transforming
arr1=np.array([[1,3,5,6],[4,5,7,2]])
arr1

# %%
arr1.shape

# %%
arr=arr1.reshape(2,4,1)
arr

# %%
arr2=np.random.randint(1,10,size=(2,4,1))
arr2

# %%
arr * arr2

# %%
#Transpose
arr2.T

# %%
arr1.T

# %%
#elemnt wise multiplication:: elemnt will multiply to elemnt
b1=np.random.randint(1,10,size=(4,3))
b2=np.random.randint(1,10,size=(4,3))
b1

# %%
b1.shape, b2.shape

# %%
b1*b2

# %%
b2

# %%
b1

# %%
b3=b2.T
b3

# %%
#dot product :_ rows will multiply with columns
np.dot(b1, b3)

# %%
c1=np.random.randint(1,10,size=(3,3))
c2=np.random.randint(1,10,size=(3,2))
c1,

# %%
np.dot(c1,c2)

# %%
quantity=np.array([[2,7,1],[9,4,16],[11,14,18],[15,18,9]])
quantity

# %%
price=np.array([10,8,12])
price

# %%
quantity.shape, price.shape

# %%
total=np.dot(quantity, price)
total
df1=pd.DataFrame(total, columns=["Total"])
df1

# %%
np.sum(total)

# %%
import pandas as pd
df=pd.DataFrame(quantity, index=["Mon","Tues","Wed","Thurs"]
                , columns=["Almond Butter","Peanut Butter","Cashew Butter"])
df

# %%
b1

# %%
b1 > b2

# %%
b1 >= b2

# %%
b1 == b2

# %%
b1

# %%
#Sorting
np.sort(b1)

# %%
np.argsort(b1)

# %%
np.argmax(b1, axis=0)

# %%
np.argmin(b1, axis=1)

# %% [markdown]
# Practical Use: Converting photo in numpy array

# %%
from matplotlib.image import imread

panda= imread('/content/panda.png')
panda

# %% [markdown]
# All These numbers in elements are color value of every pixel

# %%
panda.size, panda.shape

# %%
type(panda)

# %% [markdown]
# # **MATPLOTLIB**

# %%
# %matplotlib Inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,3,3,4,5]
y=[11,22,33,40,55]
plt.plot(x,y);

# %%
fig, ax= plt.subplots( figsize=(10,5))
ax.plot(x,y);
ax.set(title="Simple Graph", xlabel="X axis", ylabel="Y axis" );

# %%
c1=np.linspace(0, 50, 100)

# %%
fig, ax=plt.subplots()
ax.plot(c1, c1 **2);

# %%
plt.scatter(c1,c1 **2);

# %%
fig, ax=plt.subplots()
total={"Chips": 10, "Chocolate": 12, "Toffee":5 }
ax.bar(total.keys(), total.values());
ax.set(title="Shop chart", ylabel="Prices");

# %%
fig, ax=plt.subplots()
ax.barh(total.keys(), total.values());
