# %%
import pandas as pd

# %%
car=pd.read_csv('/content/9.1 car-sales-missing-data.csv')
car
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car['Odometer'].mean()
# Out:
# np.float64(92302.66666666667)

# %%
car['Odometer',]=car['Odometer'].fillna(car['Odometer'].mean())
car
# Out:
#      Make Colour  Odometer  Doors    Price    (Odometer,)
# 0  Toyota  White  150043.0    4.0   $4,000  150043.000000
# 1   Honda    Red   87899.0    4.0   $5,000   87899.000000
# 2  Toyota   Blue       NaN    3.0   $7,000   92302.666667
# 3     BMW  Black   11179.0    5.0  $22,000   11179.000000
# 4  Nissan  White  213095.0    4.0   $3,500  213095.000000
# 5  Toyota  Green       NaN    4.0   $4,500   92302.666667
# 6   Honda    NaN       NaN    4.0   $7,500   92302.666667
# 7   Honda   Blue       NaN    4.0      NaN   92302.666667
# 8  Toyota  White   60000.0    NaN      NaN   60000.000000
# 9     NaN  White   31600.0    4.0   $9,700   31600.000000

# %%
car['Price'].dropna()
# Out:
# 0     $4,000
# 1     $5,000
# 2     $7,000
# 3    $22,000
# 4     $3,500
# 5     $4,500
# 6     $7,500
# 9     $9,700
# Name: Price, dtype: object

# %%
car1 = car
car1.head()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car['Safety']= True
car
# Out:
#      Make Colour  Odometer  Doors    Price  Safety
# 0  Toyota  White  150043.0    4.0   $4,000    True
# 1   Honda    Red   87899.0    4.0   $5,000    True
# 2  Toyota   Blue       NaN    3.0   $7,000    True
# 3     BMW  Black   11179.0    5.0  $22,000    True
# 4  Nissan  White  213095.0    4.0   $3,500    True
# 5  Toyota  Green       NaN    4.0   $4,500    True
# 6   Honda    NaN       NaN    4.0   $7,500    True
# 7   Honda   Blue       NaN    4.0      NaN    True
# 8  Toyota  White   60000.0    NaN      NaN    True
# 9     NaN  White   31600.0    4.0   $9,700    True

# %%
car.drop('Safety', axis=1)
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car
# Out:
#      Make Colour  Odometer  Doors    Price  Safety
# 0  Toyota  White  150043.0    4.0   $4,000    True
# 1   Honda    Red   87899.0    4.0   $5,000    True
# 2  Toyota   Blue       NaN    3.0   $7,000    True
# 3     BMW  Black   11179.0    5.0  $22,000    True
# 4  Nissan  White  213095.0    4.0   $3,500    True
# 5  Toyota  Green       NaN    4.0   $4,500    True
# 6   Honda    NaN       NaN    4.0   $7,500    True
# 7   Honda   Blue       NaN    4.0      NaN    True
# 8  Toyota  White   60000.0    NaN      NaN    True
# 9     NaN  White   31600.0    4.0   $9,700    True

# %%
car.sample(frac=0.2)
# Out:
#      Make Colour  Odometer  Doors   Price  Safety
# 6   Honda    NaN       NaN    4.0  $7,500    True
# 8  Toyota  White   60000.0    NaN     NaN    True
