# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('/content/c_data.csv')

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual_Income_k$  Spending_Score
# 0             1    Male   42                68              51
# 1             2    Male   27                24              96
# 2             3  Female   30                65              46
# 3             4  Female   20                25              62
# 4             5  Female   62                97               8
# ..          ...     ...  ...               ...             ...
# 245         246  Female   67                92               8
# 246         247  Female   20                24              82
# 247         248    Male   45                54              34
# 248         249    Male   36                45              30
# 249         250  Female   47                51              61
#
# [250 rows x 5 columns]

# %%
data=df.iloc[:, 3:5].values

# %%
plt.scatter(data[:, 0], data[:, 1], c='black')

# %%
from sklearn.cluster import KMeans

# %%
wc=[]
for i in range(1,11):
  kmeans=KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
  kmeans.fit(data)
  wc.append(kmeans.inertia_)
plt.plot(range(1,11), wc)

# %%
from sklearn.cluster import DBSCAN
db=DBSCAN(eps=3, min_samples=3)
labels=db.fit_predict(data)
un_labels=np.unique(labels)

# %%
plt.scatter(data[labels == -1,0], data[labels == -1,1], c='black')
plt.scatter(data[labels == 0,0], data[labels == 0,1], c='red')
plt.scatter(data[labels == 1,0], data[labels == 1,1], c='red')
plt.scatter(data[labels == 2,0], data[labels == 2,1], c='red')
plt.scatter(data[labels == 3,0], data[labels == 3,1], c='red')
plt.scatter(data[labels == 4,0], data[labels == 4,1], c='red')
plt.scatter(data[labels == 5,0], data[labels == 5,1], c='red')
plt.scatter(data[labels == 6,0], data[labels == 6,1], c='red')
plt.scatter(data[labels == 7,0], data[labels == 7,1], c='red')
plt.scatter(data[labels == 8,0], data[labels == 8,1], c='red')
plt.scatter(data[labels == 9,0], data[labels == 9,1], c='red')
